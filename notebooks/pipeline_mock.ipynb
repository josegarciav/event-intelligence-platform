# %% [markdown]
# # Event Ingestion Pipeline Testing
#
# This notebook tests the **config-driven** event ingestion pipeline.
# All sources (Ra.co, Ticketmaster, etc.) are created through `PipelineFactory`
# using YAML configuration — no source-specific code needed.
#
# **Pipeline flow:**
# 1. Factory reads `ingestion.yaml` and creates pipelines
# 2. Each pipeline fetches raw data via its adapter (GraphQL / REST)
# 3. FieldMapper extracts + transforms fields per config
# 4. TaxonomyMapper assigns Human Experience Taxonomy dimensions
# 5. Events are normalized to `EventSchema` and optionally enriched by LLM

# %%
import sys
import os
import logging


# Setup path — point to services/api so src.* imports work
API_ROOT = os.path.abspath(os.path.join("..", "services", "api"))
if API_ROOT not in sys.path:
    sys.path.insert(0, API_ROOT)

# Setup path — point to services/scrapping so scrapping.* imports work
SCRAPPING_ROOT = os.path.abspath(os.path.join("..", "services", "scrapping"))
if SCRAPPING_ROOT not in sys.path:
    sys.path.insert(0, SCRAPPING_ROOT)

# Enable logging
logging.basicConfig(
    level=logging.INFO,
    format="%(name)s - %(levelname)s - %(message)s",
)


print(f"API root: {API_ROOT}")
print(f"Scrapping root: {SCRAPPING_ROOT}")
print("Setup complete")
# Out:
# API root: /Users/josegarcia/Documents/GitHub/event-intelligence-platform/services/api
# Scrapping root: /Users/josegarcia/Documents/GitHub/event-intelligence-platform/services/scrapping
# Setup complete

# %% [markdown]
# ## Step 1: PipelineFactory — List All Configured Sources
#
# The factory reads `ingestion.yaml` and can create pipelines for any enabled source.

# %%
from src.ingestion.factory import PipelineFactory

factory = PipelineFactory()

print("Configured Sources:")
print("=" * 50)
for name, info in factory.list_sources().items():
    status = "ENABLED" if info["enabled"] else "disabled"
    print(f"  {name:20} type={info['type']:10} [{status}]")

print(f"\nEnabled sources: {factory.list_enabled_sources()}")
# Out:
# Configured Sources:
# ==================================================
#   ra_co                type=api        [ENABLED]
#   ticketmaster         type=api        [disabled]
#
# Enabled sources: ['ra_co']

# %% [markdown]
# ## Step 2: Ra.co Pipeline — Multi-City Ingestion
#
# The Ra.co pipeline is created entirely from config. It uses:
# - GraphQL API adapter
# - Multi-city execution (Barcelona + Madrid via `defaults.areas`)
# - Date-window splitting for complete coverage
# - FieldMapper for extraction + transformations
# - FeatureExtractor (LLM) for taxonomy enrichment

# %%
ra_co = factory.create_pipeline("ra_co")

print(f"Pipeline: {ra_co.config.source_name}")
print(f"Source type: {ra_co.source_type.value}")
print(f"Protocol: {ra_co.source_config.protocol}")
print(f"Endpoint: {ra_co.source_config.endpoint}")
print(f"Areas: {ra_co.source_config.defaults.get('areas', {})}")
print(f"Days ahead: {ra_co.source_config.defaults.get('days_ahead')}")
print(f"Feature extractor: {ra_co.feature_extractor is not None}")
# Out:
# Pipeline: ra_co
# Source type: api
# Protocol: graphql
# Endpoint: https://ra.co/graphql
# Areas: {'Barcelona': 20, 'Madrid': 41}
# Days ahead: 120
# Feature extractor: False

# %%
# Execute Ra.co pipeline (multi-city: Barcelona + Madrid)
raco_result = ra_co.execute()

print("Ra.co Pipeline Results")
print("=" * 60)
print(f"Status: {raco_result.status.value}")
print(f"Total raw events: {raco_result.total_events_processed}")
print(f"Successful: {raco_result.successful_events}")
print(f"Failed: {raco_result.failed_events}")
print(f"Duration: {raco_result.duration_seconds:.2f}s")
print(f"Success rate: {raco_result.success_rate:.1f}%")
print(f"Cities: {raco_result.metadata.get('cities', [])}")

if raco_result.errors:
    print(f"\nErrors: {raco_result.errors}")
# Out:
# pipeline.ra_co - INFO - Starting multi-city execution: ra_co_20260211_195107_1bf5c7cf (2 cities)
# pipeline.ra_co - INFO - Fetching events for Barcelona (area_id=20)...
# pipeline.ra_co - INFO -   Barcelona: sliding window fetch [2026-02-11..2026-06-11] (capacity=500/call, window=168h)
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 3/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 39 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 139 total events across 3 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-02-11..2026-02-18] 139/139 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 3/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 12 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 112 total events across 3 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-02-18..2026-02-25] 112/112 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 35 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 85 total events across 2 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-02-25..2026-03-04] 85/85 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 38 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 38 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-03-04..2026-03-11] 38/38 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 35 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 35 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-03-11..2026-03-18] 35/35 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 33 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 33 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-03-18..2026-03-25] 33/33 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 26 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 26 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-03-25..2026-04-01] 26/26 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 14 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 14 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-04-01..2026-04-08] 14/14 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 16 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 16 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-04-08..2026-04-15] 16/16 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 11 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 11 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-04-15..2026-04-22] 11/11 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 8 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 8 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-04-22..2026-04-29] 8/8 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 9 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 9 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-04-29..2026-05-06] 9/9 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 4 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 4 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-05-06..2026-05-13] 4/4 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 3 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 3 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-05-13..2026-05-20] 3/3 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 2 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 2 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-05-20..2026-05-27] 2/2 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 3 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 3 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-05-27..2026-06-03] 3/3 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 3 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 3 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-06-03..2026-06-10] 3/3 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 2 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 2 total events across 1 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-06-10..2026-06-11] 2/2 events
# pipeline.ra_co - INFO -   Barcelona: sliding window complete — 543 total raw events
# pipeline.ra_co - INFO -   Barcelona: 543 raw events fetched
# pipeline.ra_co - INFO - Fetching events for Madrid (area_id=41)...
# pipeline.ra_co - INFO -   Madrid: sliding window fetch [2026-02-11..2026-06-11] (capacity=500/call, window=168h)
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 27 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 77 total events across 2 pages
# pipeline.ra_co - INFO -   Madrid: [2026-02-11..2026-02-18] 77/77 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 35 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 85 total events across 2 pages
# pipeline.ra_co - INFO -   Madrid: [2026-02-18..2026-02-25] 85/85 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 14 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 64 total events across 2 pages
# pipeline.ra_co - INFO -   Madrid: [2026-02-25..2026-03-04] 64/64 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 40 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 40 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-03-04..2026-03-11] 40/40 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 27 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 27 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-03-11..2026-03-18] 27/27 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 25 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 25 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-03-18..2026-03-25] 25/25 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 29 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 29 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-03-25..2026-04-01] 29/29 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 9 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 9 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-04-01..2026-04-08] 9/9 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 6 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 6 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-04-08..2026-04-15] 6/6 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 11 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 11 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-04-15..2026-04-22] 11/11 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 7 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 7 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-04-22..2026-04-29] 7/7 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 6 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 6 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-04-29..2026-05-06] 6/6 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 3 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 3 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-05-06..2026-05-13] 3/3 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 6 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 6 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-05-13..2026-05-20] 6/6 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 2 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 2 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-05-20..2026-05-27] 2/2 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 6 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 6 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-05-27..2026-06-03] 6/6 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 3 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 3 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-06-03..2026-06-10] 3/3 events
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 0 total events across 1 pages
# pipeline.ra_co - WARNING -   Madrid: [2026-06-10..2026-06-11] no results or fetch failed, advancing
# pipeline.ra_co - INFO -   Madrid: sliding window complete — 406 total raw events
# pipeline.ra_co - INFO -   Madrid: 406 raw events fetched
# pipeline.ra_co - INFO - Total raw events across all cities: 949
# pipeline.ra_co - INFO - Deduplication: 949 -> 899 events
# pipeline.ra_co - INFO - Multi-city pipeline completed: 899/949 successful
# Ra.co Pipeline Results
# ============================================================
# Status: partial_success
# Total raw events: 949
# Successful: 899
# Failed: 50
# Duration: 1610.28s
# Success rate: 94.7%
# Cities: ['Barcelona', 'Madrid']

# %%
# Show sample normalized events
if raco_result.events:
    print(f"Sample Events ({len(raco_result.events)} total):")
    print("=" * 70)

    for i, event in enumerate(raco_result.events[:5]):
        print(f"\n[{i+1}] {event.title}")
        print(f"    City: {event.location.city} | Venue: {event.location.venue_name}")
        print(f"    Date: {event.start_datetime}")
        print(f"    Type: {event.event_type} | Price: {event.price.price_raw_text}")
        print(f"    Source URL: {event.source.source_url}")
        desc = (event.description or 'N/A')[:120]
        print(f"    Description: {desc}...")
        print(f"    Quality: {event.data_quality_score:.2f}")
else:
    print("No events fetched. Check pipeline logs above for errors.")
# Out:
# Sample Events (899 total):
# ======================================================================
#
# [1] NØVAROOM
#     City: Barcelona | Venue: City Hall
#     Date: 2026-02-11 23:59:00+00:00
#     Type: nightlife | Price: 0
#     Source URL: https://ra.co/events/2365398
#     Description: NØVAROOM nace como un nuevo concepto enfocado en el groove, la conexión y la energía del club. Un espacio donde la músic...
#     Quality: 0.55
#
# [2] Mise en Place
#     City: Barcelona | Venue: Macarena Club
#     Date: 2026-02-11 23:59:00+00:00
#     Type: nightlife | Price: 10€
#     Source URL: https://ra.co/events/2348941
#     Description: N/A...
#     Quality: 0.55
#
# [3] MEN (All Night Long)
#     City: Barcelona | Venue: Moog Club
#     Date: 2026-02-11 23:59:00+00:00
#     Type: nightlife | Price: None
#     Source URL: https://ra.co/events/2338538
#     Description: Men llegó hace unos años a Barcelona después de recorrer todos los clubs de su Cantábrico natal (La Real, Locomotive, Wh...
#     Quality: 0.55
#
# [4] TIMEZERO SHOWCASE
#     City: Barcelona | Venue: Garage 442
#     Date: 2026-02-11 22:30:00+00:00
#     Type: nightlife | Price: 0
#     Source URL: https://ra.co/events/2314325
#     Description: TIMEZERO RECORDS arrives in Barcelona for the first time with a line-up of Italian and British DJs from its label. Don't...
#     Quality: 0.55
#
# [5] LeMichael, Alessio Panasiti
#     City: Barcelona | Venue: Switch Bar
#     Date: 2026-02-11 22:00:00+00:00
#     Type: nightlife | Price: 0€
#     Source URL: https://ra.co/events/2366329
#     Description: N/A...
#     Quality: 0.55

# %%
raco_result.events
# Out:
# [EventSchema(event_id='430a341e-2b4e-5c50-ae7f-e565ea0569c5', title='NØVAROOM', description='NØVAROOM nace como un nuevo concepto enfocado en el groove, la conexión y la energía del club. Un espacio donde la música marca el ritmo y la pista se convierte en un punto de encuentro real. El proyecto se mueve entre la Tech House y el Minimal / Deep Tech , con sets diseñados para construir una narrativa progresiva, cuidando el detalle, la dinámica y la respuesta del público. NØVAROOM llega a City Hall Barcelona para transformar la sala en un viaje nocturno guiado por el groove, la intensidad y la conexión con la pista.', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 2,
gánica tanto en espacios íntimos como en grandes escenarios. JODITA TECHNO Somos la comunidad más manija de electrónica que podés descubrir en esta ciudad. Integrada por gente buena vibra, amigos de amigos (: La conformamos DJs residentes de clubes míticos de Madrid, y fieles seguidores de la jodita, haciendo de cada encuentro una fecha épica, y dándolo todo en cada noche de electrónica en la ciudad. SOLO MANIJAS, SOLO ELECTRÓNICA. *Organizada por JODITA, para JODITA. Es nuestra fiesta, la fiesta de todos.', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 5, 30, 23, 0, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 5, 31, 8, 0, tzinfo=datetime.timezone.utc), duration_minutes=540, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='TBA - La Finca', street_address=None, city='Madrid', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='nightlife', format='in_person', capacity=None, age_restriction=None, price=PriceInfo(currency='EUR', is_free=True, minimum_price=None, maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text=None), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='TBA - La Finca', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[], image_url=None, media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2366922', source_url='https://ra.co/events/2366922', compressed_html=None, updated_at=datetime.datetime(2026, 2, 11, 20, 17, 49, 418256, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 11, 20, 17, 49, 418278, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=44, interested_count=None, views_count=None, shares_count=None, comments_count=None, likes_count=None, last_updated=None), data_quality_score=0.55, normalization_errors=[], tags=[], custom_fields={'artists': [], 'is_ticketed': True}, created_at=datetime.datetime(2026, 2, 11, 20, 17, 49, 418469, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 11, 20, 17, 49, 418473, tzinfo=datetime.timezone.utc)),
#  EventSchema(event_id='20d928ec-9637-5e9c-8a5a-ffa6de982550', title='BC FESTIVAL', description='El BCFestival vuelve más fuerte que nunca. Dos días donde el techno retumbará entre los campos y el río de Villalgordo del Júcar (Albacete), convirtiendo este rincón de La Mancha en el epicentro del sonido electrónico nacional e internacional. En 2026 ampliamos la experiencia: dos días de música, naturaleza y libertad total. Dos jornadas en las que el ritmo no se detiene, las luces pintan el cielo y cada beat se siente al 100%. 2 DÍAS, 2 EXPERIENCIAS. El entorno lo hace único. Entre árboles, agua y horizontes abiertos, el festival se funde con la naturaleza creando un ambiente mágico, diferente y auténtico. Aquí, la energía del público y la fuerza del paisaje se mezclan para crear algo irrepetible. Este año, el cartel sube el nivel: DJ internacionales de la escena techno y artistas nacionales compartirán escenario con nuevos talentos que están marcando el futuro del género. Desde los sonidos más oscuros y profundos hasta los sets más melódicos y energéticos, cada sesión será una experiencia sensorial.', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 6, 5, 23, 0, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 6, 7, 7, 0, tzinfo=datetime.timezone.utc), duration_minutes=1920, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='TBA - Villalgordo del Júcar, Albacete', street_address=None, city='Madrid', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='festival', format='in_person', capacity=None, age_restriction=None, price=PriceInfo(currency='EUR', is_free=True, minimum_price=None, maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text='€'), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='TBA - Villalgordo del Júcar, Albacete', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[], image_url=None, media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2354537', source_url='https://ra.co/events/2354537', compressed_html=None, updated_at=datetime.datetime(2026, 2, 11, 20, 17, 52, 804895, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 11, 20, 17, 52, 804922, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=11, interested_count=None, views_count=None, shares_count=None, comments_count=None, likes_count=None, last_updated=None), data_quality_score=0.55, normalization_errors=[], tags=[], custom_fields={'artists': []}, created_at=datetime.datetime(2026, 2, 11, 20, 17, 52, 805141, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 11, 20, 17, 52, 805143, tzinfo=datetime.timezone.utc)),
#  EventSchema(event_id='add5c85d-c88a-58c6-a662-9cb9b3be173c', title='SERVING CUNT FEST with SUCHI', description='_We are a club committed to creating an equal and safe space on the dance floor where NO form of racism, homophobia, or LGTBIQA+ phobia is tolerated. Our goal is to provide a safe celebration for all.', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 6, 6, 23, 59, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 6, 7, 6, 0, tzinfo=datetime.timezone.utc), duration_minutes=361, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='Cadavra', street_address='C. del Caballero de Gracia, 10, Centro, 28013 Madrid, Spain', city='Madrid', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='nightlife', format='in_person', capacity=1, age_restriction=None, price=PriceInfo(currency='EUR', is_free=False, minimum_price=Decimal('15'), maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text='15'), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='Cadavra', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[], image_url=None, media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2358292', source_url='https://ra.co/events/2358292', compressed_html=None, updated_at=datetime.datetime(2026, 2, 11, 20, 17, 54, 505186, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 11, 20, 17, 54, 505208, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=2, interested_count=None, views_count=None, shares_count=None, comments_count=None, likes_count=None, last_updated=None), data_quality_score=0.6000000000000001, normalization_errors=[], tags=[], custom_fields={'artists': [], 'is_ticketed': True}, created_at=datetime.datetime(2026, 2, 11, 20, 17, 54, 505387, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 11, 20, 17, 54, 505392, tzinfo=datetime.timezone.utc))]

# %% [markdown]
# ## Step 3: Ticketmaster Pipeline (REST API)
#
# Ticketmaster uses a REST API (not GraphQL), proving the pipeline is source-agnostic.
#
# **Note:** Requires `TICKETMASTER_API_KEY` environment variable. If not set, this section is skipped.

# %%
tm_result = None
tm_api_key = os.environ.get("TICKETMASTER_API_KEY")

if tm_api_key:
    ticketmaster = factory.create_pipeline("ticketmaster")
    print(f"Pipeline: {ticketmaster.config.source_name}")
    print(f"Protocol: {ticketmaster.source_config.protocol}")
    print(f"Endpoint: {ticketmaster.source_config.endpoint}")

    tm_result = ticketmaster.execute(
        city="Barcelona",
        country_code="ES",
    )

    print("\nTicketmaster Results")
    print("=" * 60)
    print(f"Status: {tm_result.status.value}")
    print(f"Total: {tm_result.total_events_processed}")
    print(f"Successful: {tm_result.successful_events}")
    print(f"Duration: {tm_result.duration_seconds:.2f}s")
else:
    print("TICKETMASTER_API_KEY not set — skipping Ticketmaster pipeline.")
    print("Set the env var and re-run to test REST API ingestion.")
# Out:
# TICKETMASTER_API_KEY not set — skipping Ticketmaster pipeline.
# Set the env var and re-run to test REST API ingestion.

# %% [markdown]
# ## Step 4: Multi-Source Aggregation
#
# Combine events from all sources and deduplicate.

# %% [markdown]
# ## Alternative: Orchestrator Pattern
#
# The `PipelineOrchestrator` executes all enabled pipelines and provides
# cross-source deduplication in a single call.

# %%
from src.ingestion.orchestrator import load_orchestrator_from_config

config_path = os.path.join(API_ROOT, "src", "configs", "ingestion.yaml")
orchestrator = load_orchestrator_from_config(config_path)

print("Orchestrator pipelines:")
for p in orchestrator.list_pipelines():
    print(f"  {p}")

# Execute all enabled pipelines through orchestrator
pipeline_results = orchestrator.execute_all_pipelines()

for name, result in pipeline_results.items():
    print(f"\n{name}: {result.status.value} — {result.successful_events}/{result.total_events_processed} events")

# Access the ra_co result specifically
raco_result = pipeline_results.get("ra_co")
print(f"\nRa.co events: {raco_result.successful_events if raco_result else 0}")

# %%
# Deduplicate across all pipeline results using orchestrator
all_events = orchestrator.deduplicate_results(pipeline_results)

print(f"Total deduplicated events across all sources: {len(all_events)}")

# Count by source
from collections import Counter
source_counts = Counter(e.source.source_name for e in all_events)
print("\nEvents by source:")
for source, count in source_counts.items():
    print(f"  {source}: {count}")

# Count by city
city_counts = Counter(e.location.city for e in all_events)
print("\nEvents by city:")
for city, count in sorted(city_counts.items(), key=lambda x: -x[1]):
    print(f"  {city}: {count}")

# %% [markdown]
# ## Step 5: DataFrame Visualization
#
# Convert events to a comprehensive DataFrame using `pipeline.to_dataframe()`.

# %%
# Use the orchestrator's pipeline to access to_dataframe
ra_co_pipeline = orchestrator.get_pipeline("ra_co")
df = ra_co_pipeline.to_dataframe(all_events)

print(f"DataFrame shape: {df.shape}")
print(f"\nColumns ({len(df.columns)} total):")
for col in df.columns:
    print(f"  {col}")

# %%
# Show key columns
df
# Out:
#                                  event_id                          title  \
# 0    430a341e-2b4e-5c50-ae7f-e565ea0569c5                       NØVAROOM
# 1    98d7ef79-e1a3-5fb7-8a7d-a84eb3b0d784                  Mise en Place
# 2    7d2f32b8-e581-515b-823d-bde03d2be99e           MEN (All Night Long)
# 3    1aeca039-a388-533f-99b8-8126979af7a7             TIMEZERO SHOWCASE
# 4    a59da926-3a44-59c8-9eb3-41a3eb1a303f    LeMichael, Alessio Panasiti
# ..                                    ...                            ...
# 893  ecd894a8-151a-570a-be1c-5e6fbe8bca3c      Sigh.CLUB with P.O (live)
# 894  7ea36eed-46bc-5a03-aa3b-048a8e3916b6            PervertMX en Madrid
# 895  82dd450f-0771-5a7f-b82e-a98c9827c190  MARTIN FREDES - Jodita Techno
# 896  20d928ec-9637-5e9c-8a5a-ffa6de982550                    BC FESTIVAL
# 897  add5c85d-c88a-58c6-a662-9cb9b3be173c   SERVING CUNT FEST with SUCHI
#
#                                            description  \
# 0    NØVAROOM nace como un nuevo concepto enfocado ...
# 1
# 2    Men llegó hace unos años a Barcelona después d...
# 3    TIMEZERO RECORDS arrives in Barcelona for the ...
# 4
# ..                                                 ...
# 893  __We are a club committed to creating an equal...
# 894
# 895  JODITA PROGRESSIVE MADRID Después de ver el at...
# 896  El BCFestival vuelve más fuerte que nunca. Dos...
# 897  _We are a club committed to creating an equal ...
#
#                start_datetime              end_datetime  duration_minutes  \
# 0   2026-02-11 23:59:00+00:00 2026-02-12 05:00:00+00:00               301
# 1   2026-02-11 23:59:00+00:00 2026-02-12 05:00:00+00:00               301
# 2   2026-02-11 23:59:00+00:00 2026-02-12 05:00:00+00:00               301
# 3   2026-02-11 22:30:00+00:00 2026-02-12 02:30:00+00:00               240
# 4   2026-02-11 22:00:00+00:00 2026-02-12 02:30:00+00:00               270
# ..                        ...                       ...               ...
# 893 2026-05-29 23:59:00+00:00 2026-05-30 06:00:00+00:00               361
# 894 2026-05-30 22:00:00+00:00 2026-05-31 08:00:00+00:00               600
# 895 2026-05-30 23:00:00+00:00 2026-05-31 08:00:00+00:00               540
# 896 2026-06-05 23:00:00+00:00 2026-06-07 07:00:00+00:00              1920
# 897 2026-06-06 23:59:00+00:00 2026-06-07 06:00:00+00:00               361
#
#      is_all_day  is_recurring recurrence_pattern  \
# 0         False         False               None
# 1         False         False               None
# 2         False         False               None
# 3         False         False               None
# 4         False         False               None
# ..          ...           ...                ...
# 893       False         False               None
# 894       False         False               None
# 895       False         False               None
# 896       False         False               None
# 897       False         False               None
#
#                                             venue_name  ...  \
# 0                                            City Hall  ...
# 1                                        Macarena Club  ...
# 2                                            Moog Club  ...
# 3                                           Garage 442  ...
# 4                                           Switch Bar  ...
# ..                                                 ...  ...
# 893                                            Cadavra  ...
# 894  TBA - visita www.pervert.mx para conocer la di...  ...
# 895                                     TBA - La Finca  ...
# 896              TBA - Villalgordo del Júcar, Albacete  ...
# 897                                            Cadavra  ...
#
#     taxonomy_age_accessibility taxonomy_repeatability  \
# 0                         None                   None
# 1                         None                   None
# 2                         None                   None
# 3                         None                   None
# 4                         None                   None
# ..                         ...                    ...
# 893                       None                   None
# 894                       None                   None
# 895                       None                   None
# 896                       None                   None
# 897                       None                   None
#
#                               taxonomy_dimensions_json data_quality_score  \
# 0    [{"primary_category": "play_and_fun", "subcate...               0.55
# 1    [{"primary_category": "play_and_fun", "subcate...               0.55
# 2    [{"primary_category": "play_and_fun", "subcate...               0.55
# 3    [{"primary_category": "play_and_fun", "subcate...               0.55
# 4    [{"primary_category": "play_and_fun", "subcate...               0.55
# ..                                                 ...                ...
# 893  [{"primary_category": "play_and_fun", "subcate...               0.60
# 894  [{"primary_category": "play_and_fun", "subcate...               0.55
# 895  [{"primary_category": "play_and_fun", "subcate...               0.55
# 896  [{"primary_category": "play_and_fun", "subcate...               0.55
# 897  [{"primary_category": "play_and_fun", "subcate...               0.60
#
#     normalization_errors  tags artists custom_fields_json  \
# 0                   None  None            {"artists": []}
# 1                   None  None            {"artists": []}
# 2                   None  None            {"artists": []}
# 3                   None  None            {"artists": []}
# 4                   None  None            {"artists": []}
# ..                   ...   ...     ...                ...
# 893                 None  None            {"artists": []}
# 894                 None  None            {"artists": []}
# 895                 None  None            {"artists": []}
# 896                 None  None            {"artists": []}
# 897                 None  None            {"artists": []}
#
#                           created_at                       updated_at
# 0   2026-02-11 17:45:59.580539+00:00 2026-02-11 17:45:59.580542+00:00
# 1   2026-02-11 17:45:59.580929+00:00 2026-02-11 17:45:59.580930+00:00
# 2   2026-02-11 17:45:59.581191+00:00 2026-02-11 17:45:59.581192+00:00
# 3   2026-02-11 17:45:59.581402+00:00 2026-02-11 17:45:59.581403+00:00
# 4   2026-02-11 17:45:59.581577+00:00 2026-02-11 17:45:59.581578+00:00
# ..                               ...                              ...
# 893 2026-02-11 17:45:59.670963+00:00 2026-02-11 17:45:59.670963+00:00
# 894 2026-02-11 17:45:59.671137+00:00 2026-02-11 17:45:59.671138+00:00
# 895 2026-02-11 17:45:59.671208+00:00 2026-02-11 17:45:59.671209+00:00
# 896 2026-02-11 17:45:59.671381+00:00 2026-02-11 17:45:59.671381+00:00
# 897 2026-02-11 17:45:59.671436+00:00 2026-02-11 17:45:59.671436+00:00
#
# [898 rows x 80 columns]

# %% [markdown]
# ## Step 6: Taxonomy Enrichment
#
# View the taxonomy dimensions populated by TaxonomyMapper and FeatureExtractor.

# %%
enrichment_cols = [
    "title",
    "taxonomy_subcategory",
    "taxonomy_subcategory_name",
    "taxonomy_energy_level",
    "taxonomy_social_intensity",
    "taxonomy_cognitive_load",
    "taxonomy_physical_involvement",
    "taxonomy_cost_level",
    "taxonomy_time_scale",
    "taxonomy_environment",
    "taxonomy_emotional_output",
    "taxonomy_age_accessibility",
    "taxonomy_repeatability",
]

if not df.empty:
    available = [c for c in enrichment_cols if c in df.columns]
    print(f"Taxonomy Enrichment Data ({len(available)} columns):")
    df[available].head(10)
else:
    print("No taxonomy data — DataFrame is empty.")
# Out:
# Taxonomy Enrichment Data (13 columns):

# %% [markdown]
# ## Step 7: Summary Statistics

# %%
if df.empty:
    print("No events ingested — summary statistics unavailable.")
else:
    print("=" * 60)
    print("INGESTION SUMMARY")
    print("=" * 60)

    print(f"\nTotal events: {len(df)}")
    print(f"Average quality score: {df['data_quality_score'].mean():.3f}")

    print("\n--- By Source ---")
    print(df.groupby("source_name").size().to_string())

    print("\n--- By City ---")
    print(df.groupby("city").size().sort_values(ascending=False).to_string())

    print("\n--- By Event Type ---")
    print(df.groupby("event_type").size().sort_values(ascending=False).to_string())

    print("\n--- Free vs Paid ---")
    print(df.groupby("price_is_free").size().to_string())

    print("\n--- Date Range ---")
    print(f"Earliest: {df['start_datetime'].min()}")
    print(f"Latest:   {df['start_datetime'].max()}")
# Out:
# ============================================================
# INGESTION SUMMARY
# ============================================================
#
# Total events: 898
# Average quality score: 0.570
#
# --- By Source ---
# source_name
# ra_co    898
#
# --- By City ---
# city
# Barcelona    513
# Madrid       385
#
# --- By Event Type ---
# event_type
# nightlife    835
# party         28
# concert       27
# festival       8
#
# --- Free vs Paid ---
# price_is_free
# False    544
# True     354
#
# --- Date Range ---
# Earliest: 2026-02-11 22:00:00+00:00
# Latest:   2026-06-11 20:00:00+00:00

# %% [markdown]
# ## Step 8: Save Results (Optional)

# %%
if not df.empty:
    output_dir = "../data/raw"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/events_all_sources.parquet"
    df.to_parquet(output_path, index=False, engine='fastparquet')
    print(f"Saved {len(df)} events to {output_path}")
else:
    print("DataFrame is empty — skipping save.")
# Out:
# Saved 898 events to ../data/raw/events_all_sources.parquet

# %%
import pickle

if raco_result:
    output_dir = "../data/raw"
    os.makedirs(output_dir, exist_ok=True)
    pkl_path = f"{output_dir}/raco_result.pkl"
    with open(pkl_path, "wb") as f:
        pickle.dump(raco_result, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"Saved PipelineExecutionResult to {pkl_path}")
    print(f"  Events: {raco_result.successful_events}")
    print(f"  Status: {raco_result.status.value}")
else:
    print("No raco_result to save.")

# %% [markdown]
# ## Cleanup

# %%
# Close pipeline resources
for p_info in orchestrator.list_pipelines():
    pipeline = orchestrator.get_pipeline(p_info["name"])
    if hasattr(pipeline, "close"):
        pipeline.close()

if tm_api_key:
    ticketmaster.close()
print("Resources released.")
