# %% [markdown]
# # Event Ingestion Pipeline Testing
#
# This notebook tests the **config-driven** event ingestion pipeline.
# All sources (Ra.co, Ticketmaster, etc.) are created through `PipelineFactory`
# using YAML configuration — no source-specific code needed.
#
# **Pipeline flow:**
# 1. Factory reads `ingestion.yaml` and creates pipelines
# 2. Each pipeline fetches raw data via its adapter (GraphQL / REST)
# 3. FieldMapper extracts + transforms fields per config
# 4. TaxonomyMapper assigns Human Experience Taxonomy dimensions
# 5. Events are normalized to `EventSchema` and optionally enriched by LLM

# %%
import sys
import os
import logging


# Setup path — point to services/api so src.* imports work
API_ROOT = os.path.abspath(os.path.join("..", "services", "api"))
if API_ROOT not in sys.path:
    sys.path.insert(0, API_ROOT)

# Setup path — point to services/scrapping so scrapping.* imports work
SCRAPPING_ROOT = os.path.abspath(os.path.join("..", "services", "scrapping"))
if SCRAPPING_ROOT not in sys.path:
    sys.path.insert(0, SCRAPPING_ROOT)

# Enable logging
logging.basicConfig(
    level=logging.INFO,
    format="%(name)s - %(levelname)s - %(message)s",
)


print(f"API root: {API_ROOT}")
# print(f"Scrapping root: {SCRAPPING_ROOT}")
print("Setup complete")
# Out:
# API root: /Users/josegarcia/Documents/GitHub/event-intelligence-platform/services/api
# Setup complete

# %% [markdown]
# ## Step 1: PipelineFactory — List All Configured Sources
#
# The factory reads `ingestion.yaml` and can create pipelines for any enabled source.

# %%
from src.ingestion.factory import PipelineFactory

factory = PipelineFactory()

print("Configured Sources:")
print("=" * 50)
for name, info in factory.list_sources().items():
    status = "ENABLED" if info["enabled"] else "disabled"
    print(f"  {name:20} type={info['type']:10} [{status}]")

print(f"\nEnabled sources: {factory.list_enabled_sources()}")
# Out:
# Configured Sources:
# ==================================================
#   ra_co                type=api        [ENABLED]
#   ticketmaster         type=api        [disabled]
#
# Enabled sources: ['ra_co']

# %% [markdown]
# ## Step 2: Ra.co Pipeline — Multi-City Ingestion
#
# The Ra.co pipeline is created entirely from config. It uses:
# - GraphQL API adapter
# - Multi-city execution (Barcelona + Madrid via `defaults.areas`)
# - Date-window splitting for complete coverage
# - FieldMapper for extraction + transformations
# - FeatureExtractor (LLM) for taxonomy enrichment

# %%
ra_co = factory.create_pipeline("ra_co")

print(f"Pipeline: {ra_co.config.source_name}")
print(f"Source type: {ra_co.source_type.value}")
print(f"Protocol: {ra_co.source_config.protocol}")
print(f"Endpoint: {ra_co.source_config.endpoint}")
print(f"Areas: {ra_co.source_config.defaults.get('areas', {})}")
print(f"Days ahead: {ra_co.source_config.defaults.get('days_ahead')}")
print(f"Feature extractor: {ra_co.feature_extractor is not None}")
# Out:
# Pipeline: ra_co
# Source type: api
# Protocol: graphql
# Endpoint: https://ra.co/graphql
# Areas: {'Barcelona': 20, 'Madrid': 41}
# Days ahead: 1
# Feature extractor: False

# %%
# Execute Ra.co pipeline (multi-city: Barcelona + Madrid)
raco_result = ra_co.execute()

print("Ra.co Pipeline Results")
print("=" * 60)
print(f"Status: {raco_result.status.value}")
print(f"Total raw events: {raco_result.total_events_processed}")
print(f"Successful: {raco_result.successful_events}")
print(f"Failed: {raco_result.failed_events}")
print(f"Duration: {raco_result.duration_seconds:.2f}s")
print(f"Success rate: {raco_result.success_rate:.1f}%")
print(f"Cities: {raco_result.metadata.get('cities', [])}")

if raco_result.errors:
    print(f"\nErrors: {raco_result.errors}")
# Out:
# pipeline.ra_co - INFO - Starting multi-city execution: ra_co_20260212_183024_807782a4 (2 cities)
# pipeline.ra_co - INFO - Fetching events for Barcelona (area_id=20)...
# pipeline.ra_co - INFO -   Barcelona: sliding window fetch [2026-02-12..2026-02-13] (capacity=500/call, window=168h)
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 2/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 3 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 53 total events across 2 pages
# pipeline.ra_co - INFO -   Barcelona: [2026-02-12..2026-02-13] 53/53 events
# pipeline.ra_co - INFO -   Barcelona: sliding window complete — 53 total raw events
# pipeline.ra_co - INFO -   Barcelona: 53 raw events fetched
# pipeline.ra_co - INFO - Fetching events for Madrid (area_id=41)...
# pipeline.ra_co - INFO -   Madrid: sliding window fetch [2026-02-12..2026-02-13] (capacity=500/call, window=168h)
# src.ingestion.pipelines.apis.base_api - INFO - Fetching page 1/10...
# src.ingestion.pipelines.apis.base_api - INFO - Received 39 events (less than page_size), stopping pagination
# src.ingestion.pipelines.apis.base_api - INFO - Pagination complete: fetched 39 total events across 1 pages
# pipeline.ra_co - INFO -   Madrid: [2026-02-12..2026-02-13] 39/39 events
# pipeline.ra_co - INFO -   Madrid: sliding window complete — 39 total raw events
# pipeline.ra_co - INFO -   Madrid: 39 raw events fetched
# pipeline.ra_co - INFO - Total raw events across all cities: 92
# pipeline.ra_co - INFO - Deduplication: 92 -> 92 events
# pipeline.ra_co - INFO - Multi-city pipeline completed: 92/92 successful
# Ra.co Pipeline Results
# ============================================================
# Status: success
# Total raw events: 92
# Successful: 92
# Failed: 0
# Duration: 4.01s
# Success rate: 100.0%
# Cities: ['Barcelona', 'Madrid']

# %%
raco_result.events
# Out:
# [EventSchema(event_id='7d5d2cd4-871b-592c-ab05-37d5b7acaf00', title='Noizer pres. Ribé + Dario Duegra', description='', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 2, 12, 23, 30, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 2, 13, 5, 0, tzinfo=datetime.timezone.utc), duration_minutes=330, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='Les Enfants Brillants', street_address='Carrer de Guàrdia, 3, 08001 Barcelona', city='Barcelona', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='nightlife', format='in_person', capacity=1, age_restriction=None, price=PriceInfo(currency='EUR', is_free=True, minimum_price=None, maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text=None), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='Les Enfants Brillants', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[ArtistInfo(name='Ribé', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None), ArtistInfo(name='Dario Duegra', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None)], image_url='https://ra.co/images/events/flyer/https://images.ra.co/48c03a61579216dfad7f0e7da7dd8a0d6db84d3c.jpg', media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2352149', source_url='https://ra.co/events/2352149', compressed_html=None, source_updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 653622, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 12, 18, 30, 28, 654519, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=118, interested_count=118, views_count=None, shares_count=None, comments_count=None, likes_count=None, updated_at=None), data_quality_score=0.55, normalization_errors=[NormalizationError(message='Info: Batch contained 92 raw events from API ingestion', category=<NormalizationCategory.API_INGESTION: 'api_ingestion'>)], tags=[], custom_fields={'is_ticketed': True}, created_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655061, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655064, tzinfo=datetime.timezone.utc)),
#  EventSchema(event_id='fb9626d3-c3d9-506b-b3b4-0f38aa0d6b68', title='BRIDGE 48 - RITUALS', description='RITUALS is taking over BRIDGE_48 Once a month, BRIDGE_48 shifts into a space where music becomes guidance, the body becomes instinct, and collective energy shapes the pulse of the night. Each gathering unfolds like a ceremony, as RITUALS and its guest DJs craft an experience that reaches beyond the dance floor. Step into a path where intention, vibration, and presence converge; creating an atmosphere charged with raw expression and deep connection. A night for those who seek more than sound: a place to release, reconnect, and let something larger move through you. Get your DAY PASS Your access to feel the essence of BRIDGE_48 up close: a day to meet the community, observe the creative flow, and witness where these experiences are born. Mark your calendar and prepare to give yourself fully to movement, sound, and the moment. Because the ritual never ends.', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 2, 12, 18, 0, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 2, 12, 22, 30, tzinfo=datetime.timezone.utc), duration_minutes=270, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='Bridge 48', street_address='Carrer de Llull, 48, 08005 Barcelona, España', city='Barcelona', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='nightlife', format='in_person', capacity=1, age_restriction=None, price=PriceInfo(currency='EUR', is_free=True, minimum_price=None, maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text=None), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='Bridge 48', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[ArtistInfo(name='Blaark', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None), ArtistInfo(name='Ronze', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None), ArtistInfo(name='SAINT SINNER', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None)], image_url='https://ra.co/images/events/flyer/https://images.ra.co/9b8b846830ec39babc97e8242b48cd70ef687a09.jpg', media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2359705', source_url='https://ra.co/events/2359705', compressed_html=None, source_updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655473, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 12, 18, 30, 28, 655477, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=109, interested_count=109, views_count=None, shares_count=None, comments_count=None, likes_count=None, updated_at=None), data_quality_score=0.58, normalization_errors=[NormalizationError(message='Warning: Event start time is in the past', category=<NormalizationCategory.DATA_VALIDATION: 'data_validation'>), NormalizationError(message='Info: Batch contained 92 raw events from API ingestion', category=<NormalizationCategory.API_INGESTION: 'api_ingestion'>)], tags=[], custom_fields={'is_ticketed': True}, created_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655571, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655572, tzinfo=datetime.timezone.utc)),
#  EventSchema(event_id='f832f18f-d00d-525a-b94b-b802dacc55de', title='TEATRO HARD II HARD TECHNO SET FROM ARGENTINA I GUEST LIST', description='No es un jueves cualquiera. Es la noche donde se rompe la semana. TEATRO HARD llega a City Hall Barcelona con una sola intención: presión, energía y hard techno real. Sin pausas innecesarias, sin adornos, sin música amable. Aquí se viene a sentir el golpe desde el primer minuto hasta el cierre. Sonido duro, atmósfera industrial y una pista que responde. Luces tensas, bajos que empujan el cuerpo y una narrativa pensada para quienes entienden que el hard no se explica, se vive. Por qué venir – Hard techno crudo y contundente – Energía alta desde temprano – Público que sabe a lo que viene – City Hall en su versión más intensa GUEST LIST TILL 01', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 2, 12, 23, 59, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 2, 13, 5, 0, tzinfo=datetime.timezone.utc), duration_minutes=301, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='City Hall', street_address='Rambla de Catalunya, 4; 08007 Barcelona; Spain', city='Barcelona', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='nightlife', format='in_person', capacity=1, age_restriction=None, price=PriceInfo(currency='EUR', is_free=True, minimum_price=None, maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text=None), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='City Hall', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[], image_url='https://ra.co/images/events/flyer/https://images.ra.co/21d67b6731b968ddb9fce52ab39ab64115185402.png', media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2363654', source_url='https://ra.co/events/2363654', compressed_html=None, source_updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655840, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 12, 18, 30, 28, 655843, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=85, interested_count=85, views_count=None, shares_count=None, comments_count=None, likes_count=None, updated_at=None), data_quality_score=0.6, normalization_errors=[NormalizationError(message='Info: Batch contained 92 raw events from API ingestion', category=<NormalizationCategory.API_INGESTION: 'api_ingestion'>)], tags=[], custom_fields={'is_ticketed': True}, created_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655907, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 655909, tzinfo=datetime.timezone.utc)),
#  EventSchema(event_id='c2d416da-8af3-57be-aff9-9045667e7ae4', title='Locals', description='Jueves de artistas locales. Entrada gratis hasta la media noche.', primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 2, 12, 22, 0, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 2, 13, 3, 0, tzinfo=datetime.timezone.utc), duration_minutes=300, is_all_day=False, is_recurring=False, recurrence_pattern=None, location=LocationInfo(venue_name='7833 Soundlab', street_address='Carrer Ferlandina 29, Barcelona, 08001, Espanya', city='Barcelona', state_or_region=None, postal_code=None, country_code='ES', coordinates=None, timezone='Europe/Madrid'), event_type='nightlife', format='in_person', capacity=1, age_restriction=None, price=PriceInfo(currency='EUR', is_free=False, minimum_price=Decimal('6'), maximum_price=None, early_bird_price=None, standard_price=None, vip_price=None, price_raw_text='6€'), ticket_info=TicketInfo(url=None, is_sold_out=False, ticket_count_available=None, early_bird_deadline=None), organizer=OrganizerInfo(name='7833 Soundlab', url=None, email=None, phone=None, image_url=None, follower_count=None, verified=False), artists=[ArtistInfo(name='Arista', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None), ArtistInfo(name='Aleski', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None), ArtistInfo(name='enem', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None), ArtistInfo(name='Intruso', soundcloud_url=None, spotify_url=None, instagram_url=None, genre=None)], image_url='https://ra.co/images/events/flyer/https://images.ra.co/f095029ef91c571f1690beefb2a8721a9338c5f2.png', media_assets=[], source=SourceInfo(source_name='ra_co', source_event_id='2367339', source_url='https://ra.co/events/2367339', compressed_html=None, source_updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 657407, tzinfo=datetime.timezone.utc), ingestion_timestamp=datetime.datetime(2026, 2, 12, 18, 30, 28, 657414, tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=53, interested_count=53, views_count=None, shares_count=None, comments_count=None, likes_count=None, updated_at=None), data_quality_score=0.65, normalization_errors=[NormalizationError(message='Info: Batch contained 92 raw events from API ingestion', category=<NormalizationCategory.API_INGESTION: 'api_ingestion'>)], tags=[], custom_fields={'is_ticketed': True}, created_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 657514, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 657515, tzinfo=datetime.timezone.utc)),
#  EventSchema(event_id='52cb1a26-9486-5819-a22a-187eedb8a06c', title='Magnolia presents: Isa Rojas', description="Magnolia is a series of events conceived by Isa Rojas... The idea of the parties is to showcase some of the leading women artists in Barcelona's local and international House and Techno scene by bringing them together to perform in the fun and intimate setting of one of our city's classic clubs, Macarena Club. ++++ For our 58th edition, Isa Rojas returns for an All Night Long set. It’s a takeover where she plays exactly what she feels from the first track to the last. Join us to catch the vibe and keep the February energy going as we get ready for the special female artists joining us this year! Don’t miss this solo night and come dance with us! ++++ Chilean DJ and producer based in Barcelona, Isa Rojas creates sonic journeys that move between house and techno, driven by groove and energy. Naturally connecting with the dancefloor, her sets flow effortlessly between emotional depth and power — always guided by an elegant, immersive pulse. She has performed at renowned clubs and festivals such as Brunch Electronik, Primavera Sound, Mutek, Sakral Festival, and Nitsa, sharing the stage with artists like Solomun, Keinemusik, Recondite, and Popof. Since 2019, she has led Magnolia, a monthly event at Macarena Club with all-women lineups, dedicated to highlighting the talent of female DJs in the electronic scene. Her productions have been released on labels like This and That and My Techno Weighs a Ton, and reflect the same sensitivity she brings to the booth: acid, groove, power, and soul.", primary_category='play_and_fun', taxonomy_dimensions=[TaxonomyDimension(primary_category=<PrimaryCategory.PLAY_AND_PURE_FUN: 'play_and_fun'>, subcategory='1.4', subcategory_name=None, confidence=1.0, values=[], activity_id=None, activity_name=None, energy_level=None, social_intensity=None, cognitive_load=None, physical_involvement=None, cost_level=None, time_scale=None, environment=None, emotional_output=[], risk_level=None, age_accessibility=None, repeatability=None)], start_datetime=datetime.datetime(2026, 2, 12, 23, 59, tzinfo=datetime.timezone.utc), end_datetime=datetime.datetime(2026, 2, 13,
tzinfo=datetime.timezone.utc)), engagement=EngagementMetrics(going_count=0, interested_count=0, views_count=None, shares_count=None, comments_count=None, likes_count=None, updated_at=None), data_quality_score=0.6, normalization_errors=[NormalizationError(message='Info: Batch contained 92 raw events from API ingestion', category=<NormalizationCategory.API_INGESTION: 'api_ingestion'>)], tags=[], custom_fields={}, created_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 679541, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 2, 12, 18, 30, 28, 679542, tzinfo=datetime.timezone.utc))]

# %%
# Show sample normalized events with ARTISTS focus
if raco_result.events:
    print(f"Sample Events ({len(raco_result.events)} total):")
    print("=" * 70)

    for i, event in enumerate(raco_result.events[:10]):
        print(f"\n[{i+1}] {event.title}")
        print(f"    City: {event.location.city} | Venue: {event.location.venue_name}")
        print(f"    Date: {event.start_datetime}")
        print(f"    Type: {event.event_type} | Price: {event.price.price_raw_text}")
        print(f"    Artists: {[a.name for a in event.artists]}")
        print(f"    Source URL: {event.source.source_url}")
        desc = (event.description or 'N/A')[:120]
        print(f"    Description: {desc}...")
        print(f"    Quality: {event.data_quality_score:.2f}")
        print(f"    Engagement: going={event.engagement.going_count if event.engagement else 'N/A'}, interested={event.engagement.interested_count if event.engagement else 'N/A'}")
        print(f"    Custom fields: {event.custom_fields}")
else:
    print("No events fetched. Check pipeline logs above for errors.")
# Out:
# Sample Events (92 total):
# ======================================================================
#
# [1] Noizer pres. Ribé + Dario Duegra
#     City: Barcelona | Venue: Les Enfants Brillants
#     Date: 2026-02-12 23:30:00+00:00
#     Type: nightlife | Price: None
#     Artists: ['Ribé', 'Dario Duegra']
#     Source URL: https://ra.co/events/2352149
#     Description: N/A...
#     Quality: 0.55
#     Engagement: going=118, interested=118
#     Custom fields: {'is_ticketed': True}
#
# [2] BRIDGE 48 - RITUALS
#     City: Barcelona | Venue: Bridge 48
#     Date: 2026-02-12 18:00:00+00:00
#     Type: nightlife | Price: None
#     Artists: ['Blaark', 'Ronze', 'SAINT SINNER']
#     Source URL: https://ra.co/events/2359705
#     Description: RITUALS is taking over BRIDGE_48 Once a month, BRIDGE_48 shifts into a space where music becomes guidance, the body beco...
#     Quality: 0.58
#     Engagement: going=109, interested=109
#     Custom fields: {'is_ticketed': True}
#
# [3] TEATRO HARD II HARD TECHNO SET FROM ARGENTINA I GUEST LIST
#     City: Barcelona | Venue: City Hall
#     Date: 2026-02-12 23:59:00+00:00
#     Type: nightlife | Price: None
#     Artists: []
#     Source URL: https://ra.co/events/2363654
#     Description: No es un jueves cualquiera. Es la noche donde se rompe la semana. TEATRO HARD llega a City Hall Barcelona con una sola i...
#     Quality: 0.60
#     Engagement: going=85, interested=85
#     Custom fields: {'is_ticketed': True}
#
# [4] Locals
#     City: Barcelona | Venue: 7833 Soundlab
#     Date: 2026-02-12 22:00:00+00:00
#     Type: nightlife | Price: 6€
#     Artists: ['Arista', 'Aleski', 'enem', 'Intruso']
#     Source URL: https://ra.co/events/2367339
#     Description: Jueves de artistas locales. Entrada gratis hasta la media noche....
#     Quality: 0.65
#     Engagement: going=53, interested=53
#     Custom fields: {'is_ticketed': True}
#
# [5] Magnolia presents: Isa Rojas
#     City: Barcelona | Venue: Macarena Club
#     Date: 2026-02-12 23:59:00+00:00
#     Type: nightlife | Price: 10€
#     Artists: ['Isa Rojas']
#     Source URL: https://ra.co/events/2348942
#     Description: Magnolia is a series of events conceived by Isa Rojas... The idea of the parties is to showcase some of the leading wome...
#     Quality: 0.65
#     Engagement: going=11, interested=11
#     Custom fields: {'is_ticketed': True}
#
# [6] HARD BOUNCE [Dario, Claudia & Marc Fx]
#     City: Barcelona | Venue: M7 Club
#     Date: 2026-02-12 23:59:00+00:00
#     Type: nightlife | Price: 12
#     Artists: ['DARÍO', 'CLAUDIA (ES)']
#     Source URL: https://ra.co/events/2355806
#     Description: N/A...
#     Quality: 0.60
#     Engagement: going=10, interested=10
#     Custom fields: {'is_ticketed': True}
#
# [7] Deluka + DJ BRUCE LEE
#     City: Barcelona | Venue: Moog Club
#     Date: 2026-02-12 23:59:00+00:00
#     Type: nightlife | Price: None
#     Artists: ['Deluka']
#     Source URL: https://ra.co/events/2338553
#     Description: Deluka, DJ, productor i fundador del segell discogràfic No Signal amb seu a Berlín, és un artista italià amb un estil qu...
#     Quality: 0.60
#     Engagement: going=1, interested=1
#     Custom fields: {'is_ticketed': True}
#
# [8] COHETE: G SPOT sessions presents: DOSHA / Cucut
#     City: Barcelona | Venue: G Spot Club
#     Date: 2026-02-12 21:30:00+00:00
#     Type: nightlife | Price: None
#     Artists: ['Cucut']
#     Source URL: https://ra.co/events/2366177
#     Description: Entradas con consumición incluida ADMISION : GPOT+ 23 DISCO BAR: + 27...
#     Quality: 0.60
#     Engagement: going=0, interested=0
#     Custom fields: {'is_ticketed': True}
#
# [9] The Jabba Records at 303
#     City: Barcelona | Venue: 303 Audiophile Bar
#     Date: 2026-02-12 22:00:00+00:00
#     Type: nightlife | Price: 0/12
#     Artists: ['Balou (3)', 'BENITEZ', 'A. CASANOVA', 'FLEX.cat']
#     Source URL: https://ra.co/events/2345604
#     Description: * FIRST COME FIRST SERVED* * Entry FREE before 23pm* * After 23pm is 12e* * Our community is big and we expect a big cro...
#     Quality: 0.65
#     Engagement: going=66, interested=66
#     Custom fields: {'is_ticketed': True}
#
# [10] SOCIAL LAB / OPENING EXPERIENCE / COMO PEZ EN EL AGUA
#     City: Barcelona | Venue: TBA
#     Date: 2026-02-12 19:00:00+00:00
#     Type: nightlife | Price: 15
#     Artists: []
#     Source URL: https://ra.co/events/2362568
#     Description: SOCIAL LAB – OPENING EXPERIENCE Horario 19:00 – 22:00 HS Concepto Opening Experience no es un warm up. Es la primera par...
#     Quality: 0.65
#     Engagement: going=41, interested=41
#     Custom fields: {'is_ticketed': True}

# %% [markdown]
# ## Step 3: Raw Event Inspection (pre-normalization)
#
# Inspect how FieldMapper extracts raw fields to understand the pipeline internals.

# %%
# Inspect raw parsed_event dict BEFORE normalization
# This helps verify FieldMapper is extracting artists correctly
print("=" * 60)
print("RAW FIELD MAPPER OUTPUT (parsed_event dict)")
print("=" * 60)

if hasattr(ra_co, '_last_raw_events') and ra_co._last_raw_events:
    for i, raw in enumerate(ra_co._last_raw_events[:3]):
        print(f"\n--- Raw event {i+1} ---")
        for key in ['title', 'artists', 'attending', 'interested_count',
                     'flyer_front', 'pick_blurb', 'is_ticketed',
                     'venue_name', 'minimum_age', 'venue_latitude', 'venue_longitude']:
            print(f"  {key}: {raw.get(key, 'N/A')}")
else:
    print("No cached raw events — re-running field mapper on first page...")
    # Manually test the field mapper on a sample response
    from src.ingestion.normalization.field_mapper import FieldMapper

    mapper = FieldMapper(ra_co.source_config.field_mappings)
    print(f"  Configured field mappings: {list(ra_co.source_config.field_mappings.keys())}")
    print(f"  Artists mapping: {ra_co.source_config.field_mappings.get('artists')}")
# Out:
# ============================================================
# RAW FIELD MAPPER OUTPUT (parsed_event dict)
# ============================================================
# No cached raw events — re-running field mapper on first page...
#   Configured field mappings: ['source_event_id', 'title', 'description', 'date', 'start_time', 'end_time', 'venue_name', 'venue_address', 'venue_id', 'venue_content_url', 'city', 'country_name', 'country_code', 'minimum_age', 'artists', 'cost', 'content_url', 'image_filename', 'image_crop', 'flyer_front', 'venue_live', 'attending', 'interested_count', 'is_ticketed', 'pick_id', 'pick_blurb']
#   Artists mapping: event.artists[*].name

# %% [markdown]
# ## Step 5: Compressed HTML (raw_html) Inspection
#
# Verify that the `compressed_html` enrichment is working for RA.co events.

# %% [markdown]
# ## Step 4: Artists Field Inspection
#
# Verify that `event.artists` is populated as `List[ArtistInfo]` (not stored in `custom_fields`).

# %%
# Deep inspection of the artists field
events = raco_result.events

# Count events with/without artists
events_with_artists = [e for e in events if e.artists]
events_without_artists = [e for e in events if not e.artists]

print("=" * 60)
print("ARTISTS FIELD MAPPING INSPECTION")
print("=" * 60)
print(f"Total events: {len(events)}")
print(f"Events WITH artists: {len(events_with_artists)} ({100*len(events_with_artists)/len(events):.1f}%)")
print(f"Events WITHOUT artists: {len(events_without_artists)} ({100*len(events_without_artists)/len(events):.1f}%)")

# Verify artists are ArtistInfo objects, not in custom_fields
print("\n--- Artist type check ---")
if events_with_artists:
    sample = events_with_artists[0]
    print(f"  Type of event.artists: {type(sample.artists)}")
    print(f"  Type of first artist: {type(sample.artists[0])}")
    print(f"  First artist name: {sample.artists[0].name}")
    print(f"  'artists' in custom_fields? {'artists' in (sample.custom_fields or {})}")

# Check custom_fields does NOT contain artists anymore
print("\n--- custom_fields check (should NOT contain 'artists' key) ---")
events_with_artists_in_cf = [
    e for e in events
    if e.custom_fields and "artists" in e.custom_fields
]
print(f"Events with 'artists' in custom_fields: {events_with_artists_in_cf}")

# Show top events with most artists
print("\n--- Events with most artists ---")
sorted_by_artists = sorted(events, key=lambda e: len(e.artists), reverse=True)
for e in sorted_by_artists[:10]:
    names = [a.name for a in e.artists]
    print(f"  [{len(names)} artists] {e.title}: {names}")
# Out:
# ============================================================
# ARTISTS FIELD MAPPING INSPECTION
# ============================================================
# Total events: 92
# Events WITH artists: 72 (78.3%)
# Events WITHOUT artists: 20 (21.7%)
#
# --- Artist type check ---
#   Type of event.artists: <class 'list'>
#   Type of first artist: <class 'src.schemas.event.ArtistInfo'>
#   First artist name: Ribé
#   'artists' in custom_fields? False
#
# --- custom_fields check (should NOT contain 'artists' key) ---
# Events with 'artists' in custom_fields: []
#
# --- Events with most artists ---
#   [14 artists] RAZZCLUB: Felina presenta Latin Crush V3, Antidoto Club w Die Klar, Haivai B, Yosef: ['Genosidra', 'DJ GÄP', 'Linapary', 'BZZHOUND', 'gitano del futuro', 'MIA FLAW', 'Die Klar', 'HAIVAI B', 'Yosef (ES)', 'Diego Armando', 'Fakeguido', 'kgee', 'DJ2D2', 'JUMER']
#   [9 artists] [CANCELLED] Carnaval al Port Barcelona Pres Anah, HANIE, DJ GAMBA [From 19.00]: ['HANIE', 'DJ Gamba', 'Anah', 'ATMEN', 'ALUSH', 'Brenda Cast', 'Cetratelli', 'DISARLI', 'MNZR']
#   [8 artists] MUSA 13.02.26 𖣐 Phloem b2b Sham, ENNIO b2b HAMY, Schierke, Memory Palace + Residents: ['Phloem', 'Sham (DK)', 'ENNIO', 'HAMY', 'Memory Palace', 'Schierke', 'Doppelganger', 'Fillo Deportaberta']
#   [5 artists] Tunnel presents: Eats Everything, Piem, Alice Youngling [PleaseQuiet] Cucut, casanova, Santiago: ['Eats Everything', 'Piem', 'Alice Youngling', 'Cucut', 'Santiago']
#   [4 artists] Locals: ['Arista', 'Aleski', 'enem', 'Intruso']
#   [4 artists] The Jabba Records at 303: ['Balou (3)', 'BENITEZ', 'A. CASANOVA', 'FLEX.cat']
#   [4 artists] Studio Stereo x Kommuna pres. Alexia & La Gugga: ['Alexia (2)', 'La Gugga', 'pekkuliar', 'CMYK']
#   [4 artists] Less is More at 303: ['Nicolas Duvoisin', 'TT (NYC)', 'Kid Moss', 'Guedes']
#   [4 artists] Club Clap Back 005: 'Lovers & Friends': ['Coroco', 'DJ AMX', 'Maya Matriarch', 'Jay Jay Revlon']
#   [4 artists] 6EJOU Live · moUnique / Quelza · Verraco · Stein: ['6EJOU', 'moUnique', 'Quelza', 'Verraco']

# %%
# Inspect compressed_html field on events
print("=" * 60)
print("COMPRESSED HTML (raw_html) INSPECTION")
print("=" * 60)

events_with_html = [e for e in events if e.source.compressed_html]
events_without_html = [e for e in events if not e.source.compressed_html]

print(f"Total events: {len(events)}")
print(f"Events WITH compressed_html: {len(events_with_html)} ({100*len(events_with_html)/len(events):.1f}%)")
print(f"Events WITHOUT compressed_html: {len(events_without_html)} ({100*len(events_without_html)/len(events):.1f}%)")

if events_with_html:
    # Show sample compressed_html
    sample = events_with_html[0]
    html_text = sample.source.compressed_html
    print(f"\n--- Sample compressed_html (first event with data) ---")
    print(f"  Title: {sample.title}")
    print(f"  Source URL: {sample.source.source_url}")
    print(f"  HTML length: {len(html_text)} chars")
    print(f"  First 500 chars: {html_text[:500]}...")

    # Stats
    lengths = [len(e.source.compressed_html) for e in events_with_html]
    print(f"\n--- Compressed HTML size stats ---")
    print(f"  Min: {min(lengths)} chars")
    print(f"  Max: {max(lengths)} chars")
    print(f"  Avg: {sum(lengths)/len(lengths):.0f} chars")
else:
    print("\nNO events have compressed_html!")
    print("Check that:")
    print("  1. 'scrapping' service is importable")
    print("  2. enrichment.compressed_html.enabled = true in ingestion.yaml")
    print("  3. RA.co pages are accessible with the configured engine")
    print("  4. Check pipeline logs for HTML enrichment errors")
# Out:
# ============================================================
# COMPRESSED HTML (raw_html) INSPECTION
# ============================================================
# Total events: 92
# Events WITH compressed_html: 0 (0.0%)
# Events WITHOUT compressed_html: 92 (100.0%)
#
# NO events have compressed_html!
# Check that:
#   1. 'scrapping' service is importable
#   2. enrichment.compressed_html.enabled = true in ingestion.yaml
#   3. RA.co pages are accessible with the configured engine
#   4. Check pipeline logs for HTML enrichment errors

# %% [markdown]
# ## Step 6: Deduplication
#
# Apply `ExactMatchDeduplicator` to the pipeline results and compare before/after.

# %%
from src.ingestion.deduplication import ExactMatchDeduplicator, get_deduplicator, DeduplicationStrategy

# Apply exact match deduplication
deduplicator = ExactMatchDeduplicator()
deduplicated_events = deduplicator.deduplicate(events)

print("=" * 60)
print("DEDUPLICATION RESULTS")
print("=" * 60)
print(f"Events before dedup: {len(events)}")
print(f"Events after dedup:  {len(deduplicated_events)}")
print(f"Duplicates removed:  {len(events) - len(deduplicated_events)}")
print(f"Dedup ratio:         {100*(len(events) - len(deduplicated_events))/len(events):.1f}%")

# Show duplicates if any
if len(events) != len(deduplicated_events):
    seen = set()
    duplicates = []
    for event in events:
        venue_name = event.location.venue_name or "unknown_venue"
        key = (event.title, venue_name, str(event.start_datetime))
        if key in seen:
            duplicates.append(event)
        else:
            seen.add(key)

    print(f"\n--- Duplicate events ---")
    for d in duplicates[:20]:
        print(f"  DUP: {d.title} @ {d.location.venue_name} ({d.start_datetime})")
else:
    print("\nNo duplicates found — all events are unique.")
# Out:
# ============================================================
# DEDUPLICATION RESULTS
# ============================================================
# Events before dedup: 92
# Events after dedup:  92
# Duplicates removed:  0
# Dedup ratio:         0.0%
#
# No duplicates found — all events are unique.

# %%
# Build DataFrame from deduplicated events
df = ra_co.to_dataframe(deduplicated_events)

print(f"DataFrame shape: {df.shape}")
print(f"\nColumns ({len(df.columns)} total):")
for col in df.columns:
    print(f"  {col}")

# Show key fields for artists verification
key_cols = ["title", "artists", "custom_fields_json", "event_type", "data_quality_score"]
available = [c for c in key_cols if c in df.columns]
df[available].head(15)
# Out:
# DataFrame shape: (92, 80)
#
# Columns (80 total):
#   event_id
#   title
#   description
#   start_datetime
#   end_datetime
#   duration_minutes
#   is_all_day
#   is_recurring
#   recurrence_pattern
#   venue_name
#   street_address
#   city
#   state_or_region
#   postal_code
#   country_code
#   latitude
#   longitude
#   timezone
#   event_type
#   event_format
#   capacity
#   age_restriction
#   price_currency
#   price_is_free
#   price_minimum
#   price_maximum
#   price_early_bird
#   price_standard
#   price_vip
#   price_raw_text
#   ticket_url
#   ticket_is_sold_out
#   ticket_count_available
#   ticket_early_bird_deadline
#   organizer_name
#   organizer_url
#   organizer_email
#   organizer_phone
#   organizer_image_url
#   organizer_follower_count
#   organizer_verified
#   source_name
#   source_event_id
#   source_url
#   source_updated_at
#   source_ingestion_timestamp
#   image_url
#   media_assets_json
#   engagement_going_count
#   engagement_interested_count
#   engagement_views_count
#   engagement_shares_count
#   engagement_comments_count
#   engagement_likes_count
#   engagement_updated_at
#   primary_category
#   taxonomy_subcategory
#   taxonomy_subcategory_name
#   taxonomy_values
#   taxonomy_activity_id
#   taxonomy_activity_name
#   taxonomy_energy_level
#   taxonomy_social_intensity
#   taxonomy_cognitive_load
#   taxonomy_physical_involvement
#   taxonomy_cost_level
#   taxonomy_time_scale
#   taxonomy_environment
#   taxonomy_emotional_output
#   taxonomy_risk_level
#   taxonomy_age_accessibility
#   taxonomy_repeatability
#   taxonomy_dimensions_json
#   data_quality_score
#   normalization_errors
#   tags
#   artists
#   custom_fields_json
#   created_at
#   updated_at
#                                                 title  \
# 0                    Noizer pres. Ribé + Dario Duegra
# 1                                 BRIDGE 48 - RITUALS
# 2   TEATRO HARD II HARD TECHNO SET FROM ARGENTINA ...
# 3                                              Locals
# 4                        Magnolia presents: Isa Rojas
# 5              HARD BOUNCE [Dario, Claudia & Marc Fx]
# 6                               Deluka + DJ BRUCE LEE
# 7     COHETE: G SPOT sessions presents: DOSHA / Cucut
# 8                            The Jabba Records at 303
# 9   SOCIAL LAB / OPENING EXPERIENCE / COMO PEZ EN ...
# 10  SOCIAL LAB / CUARTA EDICION / COMUNIDAD · MUSI...
# 11                       Deep, Tech, House by Navider
# 12                                            ANK 006
# 13            RONNI & Astor - Dj Set - Jam Session 55
# 14   Boris pres. Yatti, DOVnROBS, Mocha b2b Fakhriano
#
#                                       artists     custom_fields_json  \
# 0                          Ribé, Dario Duegra  {"is_ticketed": true}
# 1                 Blaark, Ronze, SAINT SINNER  {"is_ticketed": true}
# 2                                              {"is_ticketed": true}
# 3               Arista, Aleski, enem, Intruso  {"is_ticketed": true}
# 4                                   Isa Rojas  {"is_ticketed": true}
# 5                         DARÍO, CLAUDIA (ES)  {"is_ticketed": true}
# 6                                      Deluka  {"is_ticketed": true}
# 7                                       Cucut  {"is_ticketed": true}
# 8   Balou (3), BENITEZ, A. CASANOVA, FLEX.cat  {"is_ticketed": true}
# 9                                              {"is_ticketed": true}
# 10                      Mganz, Santi Gonzalez  {"is_ticketed": true}
# 11                                    Navider  {"is_ticketed": true}
# 12                                     Popsky  {"is_ticketed": true}
# 13                                Astor, Gato                    NaN
# 14                                   DOVnROBS  {"is_ticketed": true}
#
#    event_type  data_quality_score
# 0   nightlife                0.55
# 1   nightlife                0.58
# 2   nightlife                0.60
# 3   nightlife                0.65
# 4   nightlife                0.65
# 5   nightlife                0.60
# 6   nightlife                0.60
# 7   nightlife                0.60
# 8   nightlife                0.65
# 9   nightlife                0.65
# 10  nightlife                0.65
# 11  nightlife                0.60
# 12  nightlife                0.55
# 13  nightlife                0.60
# 14  nightlife                0.60

# %% [markdown]
# ## Step 7: DataFrame Visualization & Summary

# %%
# Show engagement and artist columns together
focus_cols = [
    "title", "artists", "event_type", "city",
    "engagement_going_count", "engagement_interested_count",
    "age_restriction", "data_quality_score",
]
available = [c for c in focus_cols if c in df.columns]
df[available].head(20)
# Out:
#                                                 title  \
# 0                    Noizer pres. Ribé + Dario Duegra
# 1                                 BRIDGE 48 - RITUALS
# 2   TEATRO HARD II HARD TECHNO SET FROM ARGENTINA ...
# 3                                              Locals
# 4                        Magnolia presents: Isa Rojas
# 5              HARD BOUNCE [Dario, Claudia & Marc Fx]
# 6                               Deluka + DJ BRUCE LEE
# 7     COHETE: G SPOT sessions presents: DOSHA / Cucut
# 8                            The Jabba Records at 303
# 9   SOCIAL LAB / OPENING EXPERIENCE / COMO PEZ EN ...
# 10  SOCIAL LAB / CUARTA EDICION / COMUNIDAD · MUSI...
# 11                       Deep, Tech, House by Navider
# 12                                            ANK 006
# 13            RONNI & Astor - Dj Set - Jam Session 55
# 14   Boris pres. Yatti, DOVnROBS, Mocha b2b Fakhriano
# 15                                           PSYROOTS
# 16                  * FREE TICKETS* SPECTRUM SEQUENCE
# 17         The Dijous Saved My Life: Hakigori, Arildo
# 18                 Dr. Resin Social Club meets NIIXII
# 19             NO PROBLEM--Alejo mata//X:VI VINYL SET
#
#                                       artists event_type       city  \
# 0                          Ribé, Dario Duegra  nightlife  Barcelona
# 1                 Blaark, Ronze, SAINT SINNER  nightlife  Barcelona
# 2                                              nightlife  Barcelona
# 3               Arista, Aleski, enem, Intruso  nightlife  Barcelona
# 4                                   Isa Rojas  nightlife  Barcelona
# 5                         DARÍO, CLAUDIA (ES)  nightlife  Barcelona
# 6                                      Deluka  nightlife  Barcelona
# 7                                       Cucut  nightlife  Barcelona
# 8   Balou (3), BENITEZ, A. CASANOVA, FLEX.cat  nightlife  Barcelona
# 9                                              nightlife  Barcelona
# 10                      Mganz, Santi Gonzalez  nightlife  Barcelona
# 11                                    Navider  nightlife  Barcelona
# 12                                     Popsky  nightlife  Barcelona
# 13                                Astor, Gato  nightlife  Barcelona
# 14                                   DOVnROBS  nightlife  Barcelona
# 15                                             nightlife  Barcelona
# 16                                             nightlife  Barcelona
# 17                                     Arildo  nightlife  Barcelona
# 18                                     NIIXII  nightlife  Barcelona
# 19                           Alejo mata, X:VI  nightlife  Barcelona
#
#     engagement_going_count  engagement_interested_count age_restriction  \
# 0                      118                          118            None
# 1                      109                          109            None
# 2                       85                           85            None
# 3                       53                           53            None
# 4                       11                           11            None
# 5                       10                           10            None
# 6                        1                            1            None
# 7                        0                            0            None
# 8                       66                           66            None
# 9                       41                           41            None
# 10                      40                           40            None
# 11                      12                           12            None
# 12                       7                            7            None
# 13                       4                            4            None
# 14                       3                            3            None
# 15                       6                            6            None
# 16                       7                            7            None
# 17                       0                            0            None
# 18                       0                            0            None
# 19                       0                            0            None
#
#     data_quality_score
# 0                 0.55
# 1                 0.58
# 2                 0.60
# 3                 0.65
# 4                 0.65
# 5                 0.60
# 6                 0.60
# 7                 0.60
# 8                 0.65
# 9                 0.65
# 10                0.65
# 11                0.60
# 12                0.55
# 13                0.60
# 14                0.60
# 15                0.60
# 16                0.55
# 17                0.60
# 18                0.58
# 19                0.50

# %% [markdown]
# ## Step 7: Summary Statistics

# %%
if df.empty:
    print("No events ingested — summary statistics unavailable.")
else:
    print("=" * 60)
    print("INGESTION SUMMARY (after deduplication)")
    print("=" * 60)

    print(f"\nTotal events: {len(df)}")
    print(f"Average quality score: {df['data_quality_score'].mean():.3f}")

    print("\n--- By Source ---")
    print(df.groupby("source_name").size().to_string())

    print("\n--- By City ---")
    print(df.groupby("city").size().sort_values(ascending=False).to_string())

    print("\n--- By Event Type ---")
    print(df.groupby("event_type").size().sort_values(ascending=False).to_string())

    print("\n--- Free vs Paid ---")
    print(df.groupby("price_is_free").size().to_string())

    # Artists stats
    artists_col = df["artists"].fillna("")
    events_with_artists_df = artists_col[artists_col != ""]
    print(f"\n--- Artists ---")
    print(f"Events with artist data: {len(events_with_artists_df)} / {len(df)}")

    print("\n--- Date Range ---")
    print(f"Earliest: {df['start_datetime'].min()}")
    print(f"Latest:   {df['start_datetime'].max()}")
# Out:
# ============================================================
# INGESTION SUMMARY (after deduplication)
# ============================================================
#
# Total events: 92
# Average quality score: 0.616
#
# --- By Source ---
# source_name
# ra_co    92
#
# --- By City ---
# city
# Barcelona    53
# Madrid       39
#
# --- By Event Type ---
# event_type
# nightlife    89
# concert       2
# party         1
#
# --- Free vs Paid ---
# price_is_free
# False    53
# True     39
#
# --- Artists ---
# Events with artist data: 72 / 92
#
# --- Date Range ---
# Earliest: 2026-02-12 18:00:00+00:00
# Latest:   2026-02-13 23:59:00+00:00

# %% [markdown]
# ## Step 8: Save Results (Optional)

# %%
if not df.empty:
    output_dir = "../data/raw"
    os.makedirs(output_dir, exist_ok=True)
    output_path = f"{output_dir}/events_all_sources.parquet"
    try:
        df.to_parquet(output_path, index=False, engine='pyarrow')
    except ImportError:
        df.to_parquet(output_path, index=False, engine='fastparquet')
    print(f"Saved {len(df)} events to {output_path}")
else:
    print("DataFrame is empty — skipping save.")
# Out:
# Saved 92 events to ../data/raw/events_all_sources.parquet

# %%
import pickle

if raco_result:
    output_dir = "../data/raw"
    os.makedirs(output_dir, exist_ok=True)
    pkl_path = f"{output_dir}/raco_result.pkl"
    with open(pkl_path, "wb") as f:
        pickle.dump(raco_result, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"Saved PipelineExecutionResult to {pkl_path}")
    print(f"  Events: {raco_result.successful_events}")
    print(f"  Status: {raco_result.status.value}")
else:
    print("No raco_result to save.")
# Out:
# Saved PipelineExecutionResult to ../data/raw/raco_result.pkl
#   Events: 92
#   Status: success

# %% [markdown]
# ## Cleanup

# %%
# Close pipeline resources
ra_co.close()
print("Resources released.")
# Out:
# Resources released.
